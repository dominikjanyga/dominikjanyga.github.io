# %% [markdown]
# <a href="https://colab.research.google.com/github/dominikjanyga/dominikjanyga.github.io/blob/main/chapter_1_statistics_for_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1 - Exploratory Data Analysis

# %% [markdown]
# Goal: learn basics with tabular data structures
#
# Structured data:
# - tables

# %% [markdown]
# Data:
# - numerical
#   - discrete
#   - continuouos
# - categorical
#  - binary
#  -

# %% [markdown]
# Importing libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl

# %%
url = 'https://raw.githubusercontent.com/dominikjanyga/statistics_for_data_science/main/datasets/2D_MV_200wells.csv'
df = pd.read_csv(url)
df.head()
#print(df.iloc[0:5,:]) view the first 5 samples
# Out:
#       X     Y  facies_threshold_0.3  porosity  permeability  \
# 0   565  1485                     1    0.1184         6.170
# 1  2585  1185                     1    0.1566         6.275
# 2  2065  2865                     2    0.1920        92.297
# 3  3575  2655                     1    0.1621         9.048
# 4  1835    35                     1    0.1766         7.123
#
#    acoustic_impedance
# 0               2.009
# 1               2.864
# 2               3.524
# 3               2.157
# 4               3.979

# %%
df.describe().transpose()
# Out:
#                       count         mean          std       min          25%  \
# X                     200.0  2053.400000  1113.524641  25.00000  1112.500000
# Y                     200.0  1876.150000  1137.580160  35.00000   920.000000
# facies_threshold_0.3  200.0     1.330000     0.471393   1.00000     1.000000
# porosity              200.0     0.149300     0.032948   0.05000     0.132175
# permeability          200.0    25.287462    64.470135   0.01582     1.366750
# acoustic_impedance    200.0     3.000435     0.592201   2.00900     2.483250
#
#                              50%        75%        max
# X                     2160.00000  2915.0000  3955.0000
# Y                     1855.00000  2782.5000  3995.0000
# facies_threshold_0.3     1.00000     2.0000     2.0000
# porosity                 0.15015     0.1742     0.2232
# permeability             4.82550    14.5970   463.6410
# acoustic_impedance       2.96450     3.5270     3.9840

# %%
df_subset = df.iloc[0:5,2:7]
df_subset
# Out:
#    facies_threshold_0.3  porosity  permeability  acoustic_impedance
# 0                     1    0.1184         6.170               2.009
# 1                     1    0.1566         6.275               2.864
# 2                     2    0.1920        92.297               3.524
# 3                     1    0.1621         9.048               2.157
# 4                     1    0.1766         7.123               3.979
